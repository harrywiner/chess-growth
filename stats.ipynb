# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

import numpy as np

from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2
from library import hello_world, fetch_all_games, filter_rapid, build_rating_frame, build_rating_list

HARRY = os.environ.get("HARRY")
JOYCE = os.environ.get("JOYCE")

# %%
rapid_games = filter_rapid(fetch_all_games(HARRY))
harry_df = build_rating_frame(rapid_games, HARRY)
rapid_games = filter_rapid(fetch_all_games(JOYCE))
joyce_df = build_rating_frame(rapid_games, JOYCE)

# %%
def get_rating_time(username):
    g = filter_rapid(fetch_all_games(username))
    return build_rating_list(g, username)

import cProfile
cProfile.run("get_rating_time(HARRY)")
# Out:
#          10516696 function calls (10516432 primitive calls) in 27.971 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   27.971   27.971 335897733.py:1(get_rating_time)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:1022(_find_and_load)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
# ...

# %%
df.describe()
# Out:
#             Rating          Date
# count   314.000000  3.140000e+02
# mean    965.745223  1.638189e+09
# std     268.879664  9.675462e+06
# min     231.000000  1.618445e+09
# 25%     857.250000  1.629504e+09
# 50%     950.000000  1.637626e+09
# 75%    1204.000000  1.647130e+09
# max    1360.000000  1.656547e+09

# %%
min(df["Date"])
# Out:
# (1618444800.0, 1656547200.0)

# %%
htt_1000 = min(harry_df[harry_df["Rating"] >= 1000]["Date"])
jtt_1000 = min(joyce_df[joyce_df["Rating"] >= 1000]["Date"])

# %%
delta = min(df[df["Rating"] >= 1000]["Date"]) - min(df["Date"])

# %%
from datetime import datetime, timedelta
delta_datetime = timedelta(seconds=delta)
delta_datetime
# Out:
# datetime.timedelta(days=247)

# %%
print("Harry Games to 1000: ", len(harry_df[harry_df["Date"] <= htt_1000]))
print("Joyce Games to 1000: ", len(joyce_df[joyce_df["Date"] <= jtt_1000]))
# Out:
# Harry Games to 1000:  183
# Joyce Games to 1000:  1093

# %%
len(joyce_df)
# Out:
# 3746

# %%
joyce_df.describe()
# Out:
#             Rating          Date
# count  3746.000000  3.746000e+03
# mean    973.563267  1.622165e+09
# std     194.669004  1.068409e+07
# min     401.000000  1.607645e+09
# 25%     917.000000  1.612742e+09
# 50%    1021.000000  1.621469e+09
# 75%    1094.000000  1.629158e+09
# max    1296.000000  1.656461e+09

# %%
len(joyce_df[joyce_df["Rating"] <= 1000])
# Out:
# 1654

# %%
import cProfile 
import requests
cProfile.run("requests.get(f'https://api.chess.com/pub/player/uneatenbean/stats')")
# Out:
#          7154 function calls (7087 primitive calls) in 0.324 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         1    0.000    0.000    0.007    0.007 <frozen importlib._bootstrap>:1022(_find_and_load)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
# ...
